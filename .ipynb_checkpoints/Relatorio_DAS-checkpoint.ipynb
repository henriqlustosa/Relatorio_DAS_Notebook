# %%
## Importação das Bibliotecas utilizadas neste Fonte
import requests
import json 
import pandas as pd

# %%
#Baixa realizadas Pacientes
rel_pac_baixa = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/baixapacientes/2024-08-01/2024-08-31')
response_baixa_pac = json.loads(rel_pac_baixa.text)
df_baixa_paciente =  pd.DataFrame.from_dict(response_baixa_pac )

# %%
#Profissionais
profissionais = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/profissionais/2024-08-01/2024-08-31')
profissionais = json.loads(profissionais.text)
df_profissionais =  pd.DataFrame.from_dict(profissionais )

# %%
#Fichas de acolhimento realizadas Pacientes
rel_ficha_acolhidas = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/fichapacientesacolhidos/2024-08-01/2024-08-31')
response_ficha_acolhidas = json.loads(rel_ficha_acolhidas.text)
df_ficha_acolhidas =  pd.DataFrame.from_dict(response_ficha_acolhidas )

# %%
#Extrato realizadas Pacientes
rel_extrato = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/fichapacientes/2024-08-01/2024-08-31')
response_extrato = json.loads(rel_extrato.text)
df_extrato =  pd.DataFrame.from_dict(response_extrato)

# %%
#Dados dos Pacientes
rel_dados_pacientes = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/pacientes/2024-08-01/2024-08-31')
response_dados_pacientes = json.loads(rel_dados_pacientes.text)
df_dados_pacientes =  pd.DataFrame.from_dict(response_dados_pacientes)

# %%
# Convert the 'dt_consulta' column to datetime if it is not already
df_extrato['dt_consulta'] = pd.to_datetime(df_extrato['dt_consulta'], errors='coerce')

df_extrato[(df_extrato.prontuario == 749135) & (df_extrato.dt_consulta.dt.date==pd.to_datetime('2024-09-03').date())]
# Out:
# Empty DataFrame
# Columns: [cod_consulta, dt_consulta, setor, origem_paciente, queixa, info_complementares, usuario, status_ficha, prontuario, data_mvto, nome]
# Index: []

# %%
df_ficha_acolhidas[df_ficha_acolhidas.prontuario == 4471678]
# Out:
#       prontuario         data_acolhimento status_ficha origem_paciente  \
# 36       4471678  2024-08-31 15:47:31.044  ENC TRIAGEM  MEIOS PRÓPRIOS
# 4481     4471678  2024-08-14 14:58:15.461  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                  queixa  \
# 36                                               fadiga
# 4481  DOR DE CABEÇA DOR DE GARGANTA/DOR EM PALATO, M...
#
#      informacoes_complementares usuario_acolhimento  \
# 36                         None             H013147
# 4481                       None             H012077
#
#                                      nome descricao
# 36    DOUGLAS PEREIRA PINTO  - ATUALIZAR-     VERDE
# 4481  DOUGLAS PEREIRA PINTO  - ATUALIZAR-     VERDE

# %%
df_selected_ficha_acolhidas = df_ficha_acolhidas[['prontuario', 'data_acolhimento', 'descricao']]

# %%
df_extrato.head()
# Out:
#    cod_consulta             dt_consulta              setor origem_paciente  \
# 0       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 1       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 2       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 3       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 4       5744814 2024-08-31 23:53:34.459  PS CIRURGIA GERAL  MEIOS PRÓPRIOS
#
#                                      queixa info_complementares  usuario  \
# 0                                     TOSSE                None  H006975
# 1                                     TOSSE                None  H006975
# 2                                     TOSSE                None  X182302
# 3                                     TOSSE                None  X182302
# 4  APRESENTA SANGUE NAS FEZES COM INICIO HJ                None  H009727
#
#      status_ficha  prontuario                data_mvto  \
# 0      EM TRIAGEM    12329710  2024-08-31 23:58:43.051
# 1     ENC INTERNO    12329710  2024-08-31 23:59:16.247
# 2  EM ATENDIMENTO    12329710  2024-09-01 00:36:18.181
# 3     ALTA MEDICA    12329710  2024-09-01 00:38:04.957
# 4      EM TRIAGEM    90073826  2024-08-31 23:52:49.262
#
#                          nome
# 0               RENATO CALDIN
# 1               RENATO CALDIN
# 2               RENATO CALDIN
# 3               RENATO CALDIN
# 4  ARTHUR DOS ANJOS BOSQUETTI

# %%
df_extrato['dt_consulta_data'] = pd.to_datetime(df_extrato['dt_consulta'] , format='mixed').dt.date
df_selected_ficha_acolhidas.loc[:, 'data_acolhimento_data']  = pd.to_datetime(df_ficha_acolhidas['data_acolhimento'], format='mixed').dt.date

df_ficha_extrato_mais_acolhidos_geral = pd.merge(
    df_extrato, 
    df_selected_ficha_acolhidas, 
    left_on=["prontuario", "dt_consulta_data"], 
    right_on=["prontuario", "data_acolhimento_data"]
)
# Out:
# <ipython-input-193-819cfc04ac20>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_ficha_acolhidas.loc[:, 'data_acolhimento_data']  = pd.to_datetime(df_ficha_acolhidas['data_acolhimento'], format='mixed').dt.date

# %%
# Convert the 'dt_consulta' column to datetime if it is not already
df_ficha_extrato_mais_acolhidos_geral['dt_consulta'] = pd.to_datetime(df_ficha_extrato_mais_acolhidos_geral['dt_consulta'], errors='coerce')
df_ficha_extrato_mais_acolhidos_geral[(df_ficha_extrato_mais_acolhidos_geral.prontuario == 749135) & (df_ficha_extrato_mais_acolhidos_geral.dt_consulta.dt.date==pd.to_datetime('2024-09-03').date())].shape[0]
# Out:
# 0

# %%
# Define the array of desired statuses
#statuses = ['ALTA MEDICA', 'ALTA COM ENCAMINHAMENTO', 'DESISTENCIA'] # Tirei o tipo EVASAO

# Filter the DataFrame
#filtered_df_extrato_mais_acolhimento = df_ficha_extrato_mais_acolhidos_geral[df_ficha_extrato_mais_acolhidos_geral['status_ficha'].isin(statuses)]
filtered_df_extrato_mais_acolhimento = df_ficha_extrato_mais_acolhidos_geral

# %%
filtered_df_extrato_mais_acolhimento.head()
# Out:
#    cod_consulta             dt_consulta              setor origem_paciente  \
# 0       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 1       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 2       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 3       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 4       5744814 2024-08-31 23:53:34.459  PS CIRURGIA GERAL  MEIOS PRÓPRIOS
#
#                                      queixa info_complementares  usuario  \
# 0                                     TOSSE                None  H006975
# 1                                     TOSSE                None  H006975
# 2                                     TOSSE                None  X182302
# 3                                     TOSSE                None  X182302
# 4  APRESENTA SANGUE NAS FEZES COM INICIO HJ                None  H009727
#
#      status_ficha  prontuario                data_mvto  \
# 0      EM TRIAGEM    12329710  2024-08-31 23:58:43.051
# 1     ENC INTERNO    12329710  2024-08-31 23:59:16.247
# 2  EM ATENDIMENTO    12329710  2024-09-01 00:36:18.181
# 3     ALTA MEDICA    12329710  2024-09-01 00:38:04.957
# 4      EM TRIAGEM    90073826  2024-08-31 23:52:49.262
#
#                          nome dt_consulta_data         data_acolhimento  \
# 0               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 1               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 2               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 3               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 4  ARTHUR DOS ANJOS BOSQUETTI       2024-08-31  2024-08-31 23:52:45.156
#
#   descricao data_acolhimento_data
# 0     VERDE            2024-08-31
# 1     VERDE            2024-08-31
# 2     VERDE            2024-08-31
# 3     VERDE            2024-08-31
# 4     VERDE            2024-08-31

# %%
filtered_df_extrato_mais_acolhimento.head()
# Out:
#    cod_consulta             dt_consulta              setor origem_paciente  \
# 0       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 1       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 2       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 3       5744816 2024-08-31 23:59:16.032           PS COVID  MEIOS PRÓPRIOS
# 4       5744814 2024-08-31 23:53:34.459  PS CIRURGIA GERAL  MEIOS PRÓPRIOS
#
#                                      queixa info_complementares  usuario  \
# 0                                     TOSSE                None  H006975
# 1                                     TOSSE                None  H006975
# 2                                     TOSSE                None  X182302
# 3                                     TOSSE                None  X182302
# 4  APRESENTA SANGUE NAS FEZES COM INICIO HJ                None  H009727
#
#      status_ficha  prontuario                data_mvto  \
# 0      EM TRIAGEM    12329710  2024-08-31 23:58:43.051
# 1     ENC INTERNO    12329710  2024-08-31 23:59:16.247
# 2  EM ATENDIMENTO    12329710  2024-09-01 00:36:18.181
# 3     ALTA MEDICA    12329710  2024-09-01 00:38:04.957
# 4      EM TRIAGEM    90073826  2024-08-31 23:52:49.262
#
#                          nome dt_consulta_data         data_acolhimento  \
# 0               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 1               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 2               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 3               RENATO CALDIN       2024-08-31  2024-08-31 23:58:38.612
# 4  ARTHUR DOS ANJOS BOSQUETTI       2024-08-31  2024-08-31 23:52:45.156
#
#   descricao data_acolhimento_data
# 0     VERDE            2024-08-31
# 1     VERDE            2024-08-31
# 2     VERDE            2024-08-31
# 3     VERDE            2024-08-31
# 4     VERDE            2024-08-31

# %%
filtered_df_extrato_mais_acolhimento[(filtered_df_extrato_mais_acolhimento.cod_consulta == 5751794) | (filtered_df_extrato_mais_acolhimento.cod_consulta == 5750514)]
# Out:
# Empty DataFrame
# Columns: [cod_consulta, dt_consulta, setor, origem_paciente, queixa, info_complementares, usuario, status_ficha, prontuario, data_mvto, nome, dt_consulta_data, data_acolhimento, descricao, data_acolhimento_data]
# Index: []

# %%
df_relatorio_sem_nome_medico = filtered_df_extrato_mais_acolhimento[['data_acolhimento', 'dt_consulta', 'data_mvto','descricao', 'usuario','prontuario','nome','cod_consulta','setor','status_ficha']]

# %%
df_relatorio = pd.merge(df_profissionais, df_relatorio_sem_nome_medico, on="usuario")

df_relatorio = pd.merge(df_relatorio, df_dados_pacientes, on="prontuario")

# %%
df_relatorio = df_relatorio[['data_acolhimento', 'dt_consulta', 'data_mvto','descricao', 'nome_profissional','nome', 'prontuario','cod_consulta','setor','status_ficha','dataNascimento']]

# %%
df_relatorio
# Out:
#               data_acolhimento             dt_consulta  \
# 0      2024-08-23 06:37:52.261 2024-08-23 06:38:57.555
# 1      2024-08-23 06:37:52.261 2024-08-23 06:38:57.555
# 2      2024-08-19 21:39:29.137 2024-08-19 21:41:06.522
# 3      2024-08-19 21:39:29.137 2024-08-19 21:41:06.522
# 4      2024-08-19 21:39:29.137 2024-08-19 21:41:06.522
# ...                        ...                     ...
# 19970  2024-08-22 11:38:31.122 2024-08-22 11:39:13.331
# 19971  2024-08-22 11:38:31.122 2024-08-22 11:39:13.331
# 19972  2024-08-22 11:30:46.779 2024-08-22 11:32:44.192
# 19973  2024-08-22 11:30:46.779 2024-08-22 11:32:44.192
# 19974  2024-08-22 11:30:46.779 2024-08-22 11:32:44.192
#
#                      data_mvto descricao              nome_profissional  \
# 0      2024-08-23 07:04:33.801     VERDE  TYANNA MARIA BONFIM DE MORAES
# 1      2024-08-23 07:05:26.444     VERDE  TYANNA MARIA BONFIM DE MORAES
# 2      2024-08-19 23:00:28.709   LARANJA        LILIAM IWASAKI LOURENCO
# 3      2024-08-19 23:00:36.193   LARANJA        LILIAM IWASAKI LOURENCO
# 4      2024-08-20 01:25:49.689   LARANJA        LILIAM IWASAKI LOURENCO
# ...                        ...       ...                            ...
# 19970  2024-08-22 14:59:43.415     VERDE        GABRIELA GARCIA PERALTA
# 19971  2024-08-22 16:05:50.546     VERDE        GABRIELA GARCIA PERALTA
# 19972  2024-08-22 13:54:18.388     VERDE        GABRIELA GARCIA PERALTA
# 19973  2024-08-22 13:54:55.517     VERDE        GABRIELA GARCIA PERALTA
# 19974  2024-08-22 15:30:30.622     VERDE        GABRIELA GARCIA PERALTA
#
#                                      nome  prontuario  cod_consulta  \
# 0                  GABRIEL DOS ANJOS MELO    11692829       5694856
# 1                  GABRIEL DOS ANJOS MELO    11692829       5694856
# 2                  GABRIEL DOS ANJOS MELO    11692829       5669669
# 3                  GABRIEL DOS ANJOS MELO    11692829       5669669
# 4                  GABRIEL DOS ANJOS MELO    11692829       5669669
# ...                                   ...         ...           ...
# 19970    MARCIA NATERCIA DE PAULA MOREIRA     1090802       5686829
# 19971    MARCIA NATERCIA DE PAULA MOREIRA     1090802       5686829
# 19972  MARIA APARECIDA OLIVEIRA DO AMARAL     4612206       5686696
# 19973  MARIA APARECIDA OLIVEIRA DO AMARAL     4612206       5686696
# 19974  MARIA APARECIDA OLIVEIRA DO AMARAL     4612206       5686696
#
#                    setor     status_ficha dataNascimento dataNascimento
# 0      PS CLÍNICA MÉDICA   EM ATENDIMENTO     05/04/2007     05/04/2007
# 1      PS CLÍNICA MÉDICA  EM PROCEDIMENTO     05/04/2007     05/04/2007
# 2      PS CLÍNICA MÉDICA   EM ATENDIMENTO     05/04/2007     05/04/2007
# 3      PS CLÍNICA MÉDICA  EM PROCEDIMENTO     05/04/2007     05/04/2007
# 4      PS CLÍNICA MÉDICA      ALTA MEDICA     05/04/2007     05/04/2007
# ...                  ...              ...            ...            ...
# 19970  PS CLÍNICA MÉDICA  EM PROCEDIMENTO     24/12/1950     24/12/1950
# 19971  PS CLÍNICA MÉDICA      ALTA MEDICA     24/12/1950     24/12/1950
# 19972  PS CLÍNICA MÉDICA   EM ATENDIMENTO     15/09/1958     15/09/1958
# 19973  PS CLÍNICA MÉDICA  EM PROCEDIMENTO     15/09/1958     15/09/1958
# 19974  PS CLÍNICA MÉDICA      ALTA MEDICA     15/09/1958     15/09/1958
#
# [19975 rows x 12 columns]

# %%
# Define the path to the specific folder
folder_path = 'G:\\OneDrive - Default Directory\\OneDrive - rede.sp\\Relatorio_Excel_DAS\\'

# Save the DataFrame to an Excel file in the specified folder
df_relatorio.to_excel(folder_path + 'df_relatorio.xlsx', index=False)

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = df_relatorio.duplicated(keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(df_relatorio[duplicates])

# %%
df_baixa_paciente[(df_baixa_paciente.con_numero == 5751794) | (df_baixa_paciente.con_numero == 5750514)]

# %%
#Fichas realizadas Pacientes
rel_ficha = requests.get('http://intranethspm:5009/hspmsgh-api/relatorio/fichapacientes/2024-09-01/2024-09-09')
response_ficha = json.loads(rel_ficha.text)
df_ficha =  pd.DataFrame.from_dict(response_ficha)

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = df_baixa_paciente.duplicated(subset='prontuario', keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(df_baixa_paciente[duplicates])
# Out:
# Duplicated entries based on cod_consulta:
#       prontuario  con_numero  trg_seq  seqp            data_consulta  \
# 7       90091406     5771486   227402     5  2024-09-09 18:40:09.619
# 9        5251897     5771484   227400     5  2024-09-09 18:35:10.989
# 16      90075342     5771458   227384     5  2024-09-09 17:29:30.666
# 20      90105016     5771433   227378     5  2024-09-09 16:58:52.917
# 23       2448355     5771420   227370     5  2024-09-09 16:19:05.569
# ...          ...         ...      ...   ...                      ...
# 2150     9536368     5744836   224178     5  2024-09-01 06:16:34.173
# 2157     4471678     5744818   224094     9  2024-09-01 00:04:26.282
# 2163     4146692     5744802   224066    13  2024-08-31 22:05:31.108
# 2166     4471678     5744752   224094     9  2024-08-31 15:48:11.958
# 2167     4146692     5744719   224066    13  2024-08-31 13:28:15.501
#
#       cod_status status_ficha  usuario                data_mvto
# 7              6  ALTA MEDICA  X037772  2024-09-09 22:44:09.144
# 9              6  ALTA MEDICA  X182302  2024-09-09 22:56:46.469
# 16             6  ALTA MEDICA  R938236  2024-09-09 18:52:32.574
# 20             6  ALTA MEDICA  R938230  2024-09-09 17:47:04.244
# 23             6  ALTA MEDICA  R938236  2024-09-09 18:10:58.103
# ...          ...          ...      ...                      ...
# 2150           6  ALTA MEDICA  R937746  2024-09-01 06:56:09.396
# 2157           6  ALTA MEDICA  R938588  2024-09-01 00:50:54.345
# 2163           6  ALTA MEDICA  X182302  2024-09-01 02:24:23.051
# 2166           6  ALTA MEDICA  R938588  2024-09-01 00:50:54.345
# 2167           6  ALTA MEDICA  X182302  2024-09-01 02:24:23.051
#
# [369 rows x 9 columns]

# %%
df_baixa_paciente[df_baixa_paciente.prontuario ==4471678]
# Out:
#       prontuario  con_numero  trg_seq  seqp            data_consulta  \
# 596      4471678     5765544   226428     5  2024-09-06 14:50:49.786
# 2157     4471678     5744818   224094     9  2024-09-01 00:04:26.282
# 2166     4471678     5744752   224094     9  2024-08-31 15:48:11.958
#
#       cod_status status_ficha  usuario                data_mvto
# 596            6  ALTA MEDICA  X022707  2024-09-06 16:31:50.239
# 2157           6  ALTA MEDICA  R938588  2024-09-01 00:50:54.345
# 2166           6  ALTA MEDICA  R938588  2024-09-01 00:50:54.345

# %%
df_profissionais[df_profissionais.usuario =='X055670']
# Out:
#    rf_profissional              nome_profissional  usuario
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670

# %%
df_medico_baixa = pd.merge(df_profissionais, df_baixa_paciente, on="usuario")

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = df_medico_baixa.duplicated(subset='con_numero', keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(df_medico_baixa[duplicates])
# Out:
# Duplicated entries based on cod_consulta:
# Empty DataFrame
# Columns: [rf_profissional, nome_profissional, usuario, prontuario, con_numero, trg_seq, seqp, data_consulta, cod_status, status_ficha, data_mvto]
# Index: []

# %%
df_ficha_acolhidas[df_ficha_acolhidas.prontuario ==749135]
# Out:
#       prontuario         data_acolhimento status_ficha origem_paciente  \
# 1700      749135  2024-09-03 13:52:20.398  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                  queixa  \
# 1700  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
#
#      informacoes_complementares usuario_acolhimento                     nome  \
# 1700                       None             H013216  DALVA SANTOS DE QUEIROZ
#
#      descricao
# 1700     VERDE

# %%
df_medico_baixa[df_medico_baixa.prontuario ==749135]
# Out:
#    rf_profissional              nome_profissional  usuario  prontuario  \
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 5            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
#
#    con_numero  trg_seq  seqp            data_consulta  cod_status  \
# 0     5751794   225157     8  2024-09-03 16:38:05.449           6
# 5     5750514   225157     8  2024-09-03 13:53:10.324           6
#
#   status_ficha                data_mvto
# 0  ALTA MEDICA  2024-09-03 17:44:19.406
# 5  ALTA MEDICA  2024-09-03 17:44:19.406

# %%
df_ficha_acolhidas
# Out:
#       prontuario         data_acolhimento status_ficha origem_paciente  \
# 0        3677531  2024-09-09 23:53:47.216  ENC TRIAGEM  MEIOS PRÓPRIOS
# 1       90036385  2024-09-09 23:47:08.528  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2        1429810  2024-09-09 23:45:33.994  ENC TRIAGEM  MEIOS PRÓPRIOS
# 3        2218105  2024-09-09 23:36:28.667  ENC TRIAGEM  MEIOS PRÓPRIOS
# 4       90105354  2024-09-09 23:09:49.963  ENC TRIAGEM  MEIOS PRÓPRIOS
# ...          ...                      ...          ...             ...
# 2466    11975398  2024-09-01 00:35:48.887  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2467    90096926  2024-09-01 00:30:03.318  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2468    12022356  2024-09-01 00:11:51.179  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2469    10371441  2024-09-01 00:10:24.301  ENC TRIAGEM  MEIOS PRÓPRIOS
# 2470    90098401    2024-09-01 00:05:06.2  ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                  queixa  \
# 0          REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 1               REFERE DOR DE GARGANTA E FEBRE HA 1 DIA
# 2                                             mal estar
# 3                                PROBLEMA DA RESPIRAÇÃO
# 4             REFERE ABCESSO EM BOLSA ESCROTAL HA 1 DIA
# ...                                                 ...
# 2466                   cefaleia com do no olho esquerdo
# 2467                                      DOR  NO CORPO
# 2468                                      QUEDA DA CAMA
# 2469                                       DOR NO CORPO
# 2470  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
#
#      informacoes_complementares usuario_acolhimento  \
# 0                          None             H009727
# 1                          None             H009727
# 2                          None             H012966
# 3                          None             H009727
# 4                          None             H009727
# ...                         ...                 ...
# 2466                       None             H009727
# 2467                       None             H006975
# 2468                       None             H009727
# 2469                       None             H006975
# 2470                       None             H009727
#
#                                   nome descricao
# 0       VINICIUS NASCIMENTO DOS SANTOS     VERDE
# 1                 DEBORA CARVAJAL RAPU     VERDE
# 2       BENEDITO BERNARDINO DOS SANTOS   AMARELO
# 3               MARIA RODRIGUES MORAES  VERMELHO
# 4                   MARCIO REIS COELHO   AMARELO
# ...                                ...       ...
# 2466       JOAO AUGUSTO DE LIMA SANTOS   AMARELO
# 2467  RENATA DE FATIMA OLIVEIRA BEREZA     VERDE
# 2468            LIVIA STAMPFER ANDRADE    BRANCO
# 2469  GRAZIANE CARDOSO CASTALDI CALDIN     VERDE
# 2470            GUSTAVO ALVES TEIXEIRA     VERDE
#
# [2471 rows x 9 columns]

# %%
df_medico_baixa.head()
# Out:
#    rf_profissional              nome_profissional  usuario  prontuario  \
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 1            34177  TYANNA MARIA BONFIM DE MORAES  X055670     4916920
# 2            34177  TYANNA MARIA BONFIM DE MORAES  X055670    12169959
# 3            34177  TYANNA MARIA BONFIM DE MORAES  X055670     3324290
# 4            34177  TYANNA MARIA BONFIM DE MORAES  X055670    10295012
#
#    con_numero  trg_seq  seqp            data_consulta  cod_status  \
# 0     5751794   225157     8  2024-09-03 16:38:05.449           6
# 1     5750528   225168     5  2024-09-03 14:03:41.812           6
# 2     5750520   225162     5  2024-09-03 13:56:32.875           6
# 3     5750516   225160     5  2024-09-03 13:55:52.628           6
# 4     5750515   225166     5  2024-09-03 13:59:13.226          18
#
#   status_ficha                data_mvto
# 0  ALTA MEDICA  2024-09-03 17:44:19.406
# 1  ALTA MEDICA  2024-09-03 18:50:11.274
# 2  ALTA MEDICA  2024-09-03 17:52:42.316
# 3  ALTA MEDICA  2024-09-03 18:14:43.326
# 4  DESISTENCIA  2024-09-03 18:16:47.386

# %%
df_medico_baixa['data_consulta'] = pd.to_datetime(df_medico_baixa['data_consulta'] , format='mixed').dt.date
df_ficha_acolhidas['data_acolhimento'] = pd.to_datetime(df_ficha_acolhidas['data_acolhimento'], format='mixed').dt.date

df_ficha_acolhido_medico_baixa = pd.merge(
    df_medico_baixa, 
    df_ficha_acolhidas, 
    left_on=["prontuario", "data_consulta"], 
    right_on=["prontuario", "data_acolhimento"]
)

# %%
df_ficha_acolhido_medico_baixa.head()
# Out:
#    rf_profissional              nome_profissional  usuario  prontuario  \
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 1            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 2            34177  TYANNA MARIA BONFIM DE MORAES  X055670     4916920
# 3            34177  TYANNA MARIA BONFIM DE MORAES  X055670    12169959
# 4            34177  TYANNA MARIA BONFIM DE MORAES  X055670     3324290
#
#    con_numero  trg_seq  seqp data_consulta  cod_status status_ficha_x  \
# 0     5751794   225157     8    2024-09-03           6    ALTA MEDICA
# 1     5750514   225157     8    2024-09-03           6    ALTA MEDICA
# 2     5750528   225168     5    2024-09-03           6    ALTA MEDICA
# 3     5750520   225162     5    2024-09-03           6    ALTA MEDICA
# 4     5750516   225160     5    2024-09-03           6    ALTA MEDICA
#
#                  data_mvto data_acolhimento status_ficha_y origem_paciente  \
# 0  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 1  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2  2024-09-03 18:50:11.274       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 3  2024-09-03 17:52:42.316       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 4  2024-09-03 18:14:43.326       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                               queixa  \
# 0  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 1  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 2  DOR NO PEITO A 7 DIAS, FEZ O USO DE DIPIRONA, ...
# 3                                          S GRIPAIS
# 4                                      DOR AO URINAR
#
#   informacoes_complementares usuario_acolhimento  \
# 0                       None             H013216
# 1                       None             H013216
# 2                       None             H013216
# 3                       None             H012077
# 4                       None             H013216
#
#                               nome descricao
# 0          DALVA SANTOS DE QUEIROZ     VERDE
# 1          DALVA SANTOS DE QUEIROZ     VERDE
# 2     EDINA MATIAS GONSALES BONHIN     VERDE
# 3  ALGACIR LEITE DE ALMEIDA JUNIOR     VERDE
# 4       DAISY DE MEDEIROS MELCHIOR     VERDE

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = df_ficha_acolhido_medico_baixa.duplicated(subset='con_numero', keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(df_ficha_acolhido_medico_baixa[duplicates])
# Out:
# Duplicated entries based on cod_consulta:
#       rf_profissional                      nome_profissional  usuario  \
# 12              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 13              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 24              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 25              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 26            5741777  NEUZA ALICE NOBUKO SAWADA CHIMABUCURO  H574177
# ...               ...                                    ...      ...
# 2199         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2200         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2215         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2216         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2217         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
#
#       prontuario  con_numero  trg_seq  seqp data_consulta  cod_status  \
# 12      10564888     5749511   225090     5    2024-09-03           6
# 13      10564888     5749511   225090     5    2024-09-03           6
# 24      90096520     5749143   224994     5    2024-09-03           6
# 25      90096520     5749143   224994     5    2024-09-03           6
# 26      90096520     5749400   225052     8    2024-09-03          22
# ...          ...         ...      ...   ...           ...         ...
# 2199    12090973     5754320   225670     5    2024-09-04           6
# 2200    12090973     5754320   225670     5    2024-09-04           6
# 2215    12144846     5752116   225432     5    2024-09-04           6
# 2216    12144846     5752116   225432     5    2024-09-04           6
# 2217    12144846     5752116   225432     5    2024-09-04           6
#
#                status_ficha_x                data_mvto data_acolhimento  \
# 12                ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 13                ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 24                ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 25                ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 26    ALTA COM ENCAMINHAMENTO  2024-09-03 14:17:02.884       2024-09-03
# ...                       ...                      ...              ...
# 2199              ALTA MEDICA  2024-09-04 16:37:22.542       2024-09-04
# 2200              ALTA MEDICA  2024-09-04 16:37:22.542       2024-09-04
# 2215              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
# 2216              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
# 2217              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
#
#      status_ficha_y origem_paciente  \
# 12      ENC TRIAGEM  MEIOS PRÓPRIOS
# 13      ENC TRIAGEM  MEIOS PRÓPRIOS
# 24      ENC TRIAGEM  MEIOS PRÓPRIOS
# 25      ENC TRIAGEM  MEIOS PRÓPRIOS
# 26      ENC TRIAGEM  MEIOS PRÓPRIOS
# ...             ...             ...
# 2199    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2200    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2215    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2216    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2217    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                  queixa  \
# 12    REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 13    REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 24                          DOR NAS PERNAS, VERMELHIDAO
# 25                                            MEDICACAO
# 26                          DOR NAS PERNAS, VERMELHIDAO
# ...                                                 ...
# 2199                                             coriza
# 2200                                             coriza
# 2215                                              TOSSE
# 2216                                              TOSSE
# 2217                                              TOSSE
#
#      informacoes_complementares usuario_acolhimento  \
# 12                         None             H010367
# 13                         None             H010367
# 24                         None             H013216
# 25                         None             H013216
# 26                         None             H013216
# ...                         ...                 ...
# 2199                       None             H013147
# 2200                       None             H013147
# 2215                       None             H010269
# 2216                       None             H010269
# 2217                       None             H010269
#
#                              nome descricao
# 12            FLAVIA DESTRO SILVA     VERDE
# 13            FLAVIA DESTRO SILVA     VERDE
# 24    WANDERLIN DE SANTANA PASSOS     VERDE
# 25    WANDERLIN DE SANTANA PASSOS    BRANCO
# 26    WANDERLIN DE SANTANA PASSOS     VERDE
# ...                           ...       ...
# 2199   VALDERINO APARECIDO VALINO     VERDE
# 2200   VALDERINO APARECIDO VALINO     VERDE
# 2215            DULCINEIA FERRARI     VERDE
# 2216            DULCINEIA FERRARI     VERDE
# 2217            DULCINEIA FERRARI     VERDE
#
# [280 rows x 19 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c43cce8a7459> in <module>
# ----> 1 df_medico_baixa['data_consulta'] = pd.to_datetime(df_medico_baixa['data_consulta'])
#       2 df_ficha_acolhidas['data_acolhimento'] = pd.to_datetime(df_ficha_acolhidas['data_acolhimento'])
#       3
#       4 df_medico_baixa['data_consulta'] = pd.to_datetime(df_medico_baixa['data_consulta']).dt.date
#       5 df_ficha_acolhidas['data_acolhimento'] = pd.to_datetime(df_ficha_acolhidas['data_acolhimento']).dt.date
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048             result = arg.map(cache_array)
#    1049         else:
# -> 1050             values = convert_listlike(arg._values, format)
#    1051             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452     if format is not None and format != "mixed":
# --> 453         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     454
#     455     result, tz_parsed = objects_to_datetime64ns(
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2024-09-04 16:44:51" doesn't match format "%Y-%m-%d %H:%M:%S.%f", at position 488. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df_ficha_acolhido_medico_baixa
# Out:
# Empty DataFrame
# Columns: [rf_profissional, nome_profissional, usuario, prontuario, con_numero, trg_seq, seqp, data_consulta, cod_status, status_ficha_x, data_mvto, data_acolhimento, status_ficha_y, origem_paciente, queixa, informacoes_complementares, usuario_acolhimento, nome, descricao]
# Index: []

# %%
df_ficha_acolhido_medico_baixa_subset = df_ficha_acolhido_medico_baixa.dropna(subset=['data_consulta', 'data_acolhimento'])

# %%
df_ficha_acolhido_medico_baixa_subset.head()
# Out:
# Empty DataFrame
# Columns: [rf_profissional, nome_profissional, usuario, prontuario, con_numero, trg_seq, seqp, data_consulta, cod_status, status_ficha_x, data_mvto, data_acolhimento, status_ficha_y, origem_paciente, queixa, informacoes_complementares, usuario_acolhimento, nome, descricao]
# Index: []

# %%
num_rows = df_ficha_acolhido_medico_baixa.shape[0]
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 0

# %%
num_rows = df_medico_baixa.shape[0]
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 2169

# %%
num_rows = df_ficha_acolhidas.shape[0]
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 2471

# %%
# Count NaT (invalid dates) in 'data_consulta' and 'data_acolhimento' after the merge
num_invalid_data_consulta = df_ficha_acolhido_medico_baixa['data_consulta'].isna().sum()
num_invalid_data_acolhimento = df_ficha_acolhido_medico_baixa['data_acolhimento'].isna().sum()

# %%
# Print results
print(f"Number of invalid dates in 'data_consulta' after the merge: {num_invalid_data_consulta}")
print(f"Number of invalid dates in 'data_acolhimento' after the merge: {num_invalid_data_acolhimento}")
# Out:
# Number of invalid dates in 'data_consulta' after the merge: 0
# Number of invalid dates in 'data_acolhimento' after the merge: 0

# %%
# Convert to datetime, handling mixed formats and setting invalid ones to NaT
df_medico_baixa['data_consulta'] = pd.to_datetime(df_medico_baixa['data_consulta'], errors='coerce')
df_ficha_acolhidas['data_acolhimento'] = pd.to_datetime(df_ficha_acolhidas['data_acolhimento'], errors='coerce')

# Count NaT (invalid dates) in 'data_consulta'
num_invalid_data_consulta = df_medico_baixa['data_consulta'].isna().sum()
num_invalid_data_acolhimento = df_ficha_acolhidas['data_acolhimento'].isna().sum()

print(f"Number of invalid dates in 'data_consulta': {num_invalid_data_consulta}")
print(f"Number of invalid dates in 'data_acolhimento': {num_invalid_data_acolhimento}")
# Out:
# Number of invalid dates in 'data_consulta': 1
# Number of invalid dates in 'data_acolhimento': 2

# %%
df_ficha_acolhido_medico_baixa.shape[0]
# Out:
# 2295

# %%
df_ficha_acolhido_medico_baixa.head()
# Out:
#    rf_profissional              nome_profissional  usuario  prontuario  \
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 1            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 2            34177  TYANNA MARIA BONFIM DE MORAES  X055670     4916920
# 3            34177  TYANNA MARIA BONFIM DE MORAES  X055670    12169959
# 4            34177  TYANNA MARIA BONFIM DE MORAES  X055670     3324290
#
#    con_numero  trg_seq  seqp data_consulta  cod_status status_ficha_x  \
# 0     5751794   225157     8    2024-09-03           6    ALTA MEDICA
# 1     5750514   225157     8    2024-09-03           6    ALTA MEDICA
# 2     5750528   225168     5    2024-09-03           6    ALTA MEDICA
# 3     5750520   225162     5    2024-09-03           6    ALTA MEDICA
# 4     5750516   225160     5    2024-09-03           6    ALTA MEDICA
#
#                  data_mvto data_acolhimento status_ficha_y origem_paciente  \
# 0  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 1  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2  2024-09-03 18:50:11.274       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 3  2024-09-03 17:52:42.316       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 4  2024-09-03 18:14:43.326       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                               queixa  \
# 0  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 1  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 2  DOR NO PEITO A 7 DIAS, FEZ O USO DE DIPIRONA, ...
# 3                                          S GRIPAIS
# 4                                      DOR AO URINAR
#
#   informacoes_complementares usuario_acolhimento  \
# 0                       None             H013216
# 1                       None             H013216
# 2                       None             H013216
# 3                       None             H012077
# 4                       None             H013216
#
#                               nome descricao
# 0          DALVA SANTOS DE QUEIROZ     VERDE
# 1          DALVA SANTOS DE QUEIROZ     VERDE
# 2     EDINA MATIAS GONSALES BONHIN     VERDE
# 3  ALGACIR LEITE DE ALMEIDA JUNIOR     VERDE
# 4       DAISY DE MEDEIROS MELCHIOR     VERDE

# %%
df_ficha.head()
# Out:
#    cod_consulta              dt_consulta              setor origem_paciente  \
# 0       5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 1       5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 2       5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 3       5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 4       5771556  2024-09-09 23:48:51.647  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
#
#                                          queixa info_complementares  usuario  \
# 0  REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS                None  H009727
# 1  REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS                None  H009727
# 2  REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS                None  X340740
# 3  REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS                None  X340740
# 4                                     mal estar                None  H012966
#
#      status_ficha  prontuario                data_mvto  \
# 0      EM TRIAGEM     3677531  2024-09-09 23:54:06.624
# 1     ENC INTERNO     3677531  2024-09-09 23:54:53.538
# 2  EM ATENDIMENTO     3677531  2024-09-10 04:30:53.015
# 3          EVASAO     3677531  2024-09-10 04:30:58.529
# 4      EM TRIAGEM     1429810  2024-09-09 23:45:39.069
#
#                              nome
# 0  VINICIUS NASCIMENTO DOS SANTOS
# 1  VINICIUS NASCIMENTO DOS SANTOS
# 2  VINICIUS NASCIMENTO DOS SANTOS
# 3  VINICIUS NASCIMENTO DOS SANTOS
# 4  BENEDITO BERNARDINO DOS SANTOS

# %%
df_ficha[df_ficha.status_ficha =='ALTA MEDICA']
# Out:
#        cod_consulta              dt_consulta                         setor  \
# 25          5771550  2024-09-09 23:10:29.903             PS CIRURGIA GERAL
# 29          5771548  2024-09-09 23:03:41.355  PS ORTOPEDIA E TRAUMATOLOGIA
# 34          5771547  2024-09-09 22:51:25.589             PS CLÍNICA MÉDICA
# 40          5771546  2024-09-09 22:47:28.063                          None
# 44          5771544   2024-09-09 22:44:29.85             PS CLÍNICA MÉDICA
# ...             ...                      ...                           ...
# 11118       5744826  2024-09-01 00:36:32.033             PS CLÍNICA MÉDICA
# 11126       5744822  2024-09-01 00:12:29.149             PS CIRURGIA GERAL
# 11130       5744820  2024-09-01 00:11:03.691             PS CLÍNICA MÉDICA
# 11133       5744818  2024-09-01 00:04:26.282             PS CLÍNICA MÉDICA
# 11143       5744815  2024-09-01 00:06:31.831                      PS COVID
#
#       origem_paciente                                             queixa  \
# 25     MEIOS PRÓPRIOS          REFERE ABCESSO EM BOLSA ESCROTAL HA 1 DIA
# 29     MEIOS PRÓPRIOS                               DOR NA COLUNA LOMBAR
# 34     MEIOS PRÓPRIOS  REFERE DOR ABDOMINAL E ALTERAÇÃO DO HÁBITO INT...
# 40     MEIOS PRÓPRIOS  REFERE TER COLOCADO SVD ONTEM E HOJE COMEÇOU A...
# 44     MEIOS PRÓPRIOS  APRESENTA CARTA DE ENCAMINHAMENTO PARA REAVALI...
# ...               ...                                                ...
# 11118  MEIOS PRÓPRIOS                   cefaleia com do no olho esquerdo
# 11126  MEIOS PRÓPRIOS                                      QUEDA DA CAMA
# 11130  MEIOS PRÓPRIOS                                       DOR NO CORPO
# 11133  MEIOS PRÓPRIOS                                             fadiga
# 11143  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
#
#       info_complementares  usuario status_ficha  prontuario  \
# 25                   None  R938239  ALTA MEDICA    90105354
# 29                   None  H852958  ALTA MEDICA    90105347
# 34                   None  X340740  ALTA MEDICA    90050832
# 40                   None  X182302  ALTA MEDICA    10529758
# 44                   None  X182302  ALTA MEDICA    12165098
# ...                   ...      ...          ...         ...
# 11118                None  X182302  ALTA MEDICA    11975398
# 11126                None  R938588  ALTA MEDICA    12022356
# 11130                None  X182302  ALTA MEDICA    10371441
# 11133                None  R938588  ALTA MEDICA     4471678
# 11143                None  X182302  ALTA MEDICA    90098401
#
#                      data_mvto                                 nome
# 25     2024-09-10 02:46:54.391                   MARCIO REIS COELHO
# 29     2024-09-09 23:11:35.272          INDRA MILARDE MUNIZ FREITAS
# 34      2024-09-10 03:58:16.63            WAGNER RODRIGUES DA SILVA
# 40     2024-09-10 02:54:05.165                       ADEMAR ANSELMO
# 44     2024-09-10 03:45:42.056                 ANA PAULA DOS SANTOS
# ...                        ...                                  ...
# 11118  2024-09-01 04:23:25.857          JOAO AUGUSTO DE LIMA SANTOS
# 11126  2024-09-01 01:36:18.407               LIVIA STAMPFER ANDRADE
# 11130  2024-09-01 01:33:20.977     GRAZIANE CARDOSO CASTALDI CALDIN
# 11133  2024-09-01 00:50:54.345  DOUGLAS PEREIRA PINTO  - ATUALIZAR-
# 11143  2024-09-01 04:38:31.942               GUSTAVO ALVES TEIXEIRA
#
# [1952 rows x 11 columns]

# %%
grouped_by_status = df_baixa_paciente['status_ficha'].unique()

# %%
grouped_by_status
# Out:
# array(['ALTA MEDICA', 'ALTA COM ENCAMINHAMENTO', 'EVASAO', 'DESISTENCIA'],
#       dtype=object)

# %%
# Define the array of desired statuses
statuses = ['ALTA MEDICA', 'ALTA COM ENCAMINHAMENTO', 'DESISTENCIA'] # Tirei o tipo EVASAO

# Filter the DataFrame
filtered_df = df_ficha[df_ficha['status_ficha'].isin(statuses)]

# Display the filtered DataFrame
print("Filtered DataFrame based on status_ficha:")
print(filtered_df)
# Out:
# Filtered DataFrame based on status_ficha:
#        cod_consulta              dt_consulta                         setor  \
# 25          5771550  2024-09-09 23:10:29.903             PS CIRURGIA GERAL
# 29          5771548  2024-09-09 23:03:41.355  PS ORTOPEDIA E TRAUMATOLOGIA
# 34          5771547  2024-09-09 22:51:25.589             PS CLÍNICA MÉDICA
# 40          5771546  2024-09-09 22:47:28.063                          None
# 44          5771544   2024-09-09 22:44:29.85             PS CLÍNICA MÉDICA
# ...             ...                      ...                           ...
# 11118       5744826  2024-09-01 00:36:32.033             PS CLÍNICA MÉDICA
# 11126       5744822  2024-09-01 00:12:29.149             PS CIRURGIA GERAL
# 11130       5744820  2024-09-01 00:11:03.691             PS CLÍNICA MÉDICA
# 11133       5744818  2024-09-01 00:04:26.282             PS CLÍNICA MÉDICA
# 11143       5744815  2024-09-01 00:06:31.831                      PS COVID
#
#       origem_paciente                                             queixa  \
# 25     MEIOS PRÓPRIOS          REFERE ABCESSO EM BOLSA ESCROTAL HA 1 DIA
# 29     MEIOS PRÓPRIOS                               DOR NA COLUNA LOMBAR
# 34     MEIOS PRÓPRIOS  REFERE DOR ABDOMINAL E ALTERAÇÃO DO HÁBITO INT...
# 40     MEIOS PRÓPRIOS  REFERE TER COLOCADO SVD ONTEM E HOJE COMEÇOU A...
# 44     MEIOS PRÓPRIOS  APRESENTA CARTA DE ENCAMINHAMENTO PARA REAVALI...
# ...               ...                                                ...
# 11118  MEIOS PRÓPRIOS                   cefaleia com do no olho esquerdo
# 11126  MEIOS PRÓPRIOS                                      QUEDA DA CAMA
# 11130  MEIOS PRÓPRIOS                                       DOR NO CORPO
# 11133  MEIOS PRÓPRIOS                                             fadiga
# 11143  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
#
#       info_complementares  usuario status_ficha  prontuario  \
# 25                   None  R938239  ALTA MEDICA    90105354
# 29                   None  H852958  ALTA MEDICA    90105347
# 34                   None  X340740  ALTA MEDICA    90050832
# 40                   None  X182302  ALTA MEDICA    10529758
# 44                   None  X182302  ALTA MEDICA    12165098
# ...                   ...      ...          ...         ...
# 11118                None  X182302  ALTA MEDICA    11975398
# 11126                None  R938588  ALTA MEDICA    12022356
# 11130                None  X182302  ALTA MEDICA    10371441
# 11133                None  R938588  ALTA MEDICA     4471678
# 11143                None  X182302  ALTA MEDICA    90098401
#
#                      data_mvto                                 nome
# 25     2024-09-10 02:46:54.391                   MARCIO REIS COELHO
# 29     2024-09-09 23:11:35.272          INDRA MILARDE MUNIZ FREITAS
# 34      2024-09-10 03:58:16.63            WAGNER RODRIGUES DA SILVA
# 40     2024-09-10 02:54:05.165                       ADEMAR ANSELMO
# 44     2024-09-10 03:45:42.056                 ANA PAULA DOS SANTOS
# ...                        ...                                  ...
# 11118  2024-09-01 04:23:25.857          JOAO AUGUSTO DE LIMA SANTOS
# 11126  2024-09-01 01:36:18.407               LIVIA STAMPFER ANDRADE
# 11130  2024-09-01 01:33:20.977     GRAZIANE CARDOSO CASTALDI CALDIN
# 11133  2024-09-01 00:50:54.345  DOUGLAS PEREIRA PINTO  - ATUALIZAR-
# 11143  2024-09-01 04:38:31.942               GUSTAVO ALVES TEIXEIRA
#
# [2161 rows x 11 columns]

# %%
print(df_ficha)
# Out:
#        cod_consulta              dt_consulta              setor  \
# 0           5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA
# 1           5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA
# 2           5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA
# 3           5771558  2024-09-09 23:54:53.217  PS CLÍNICA MÉDICA
# 4           5771556  2024-09-09 23:48:51.647  PS CLÍNICA MÉDICA
# ...             ...                      ...                ...
# 11139       5744815  2024-09-01 00:06:31.831           PS COVID
# 11140       5744815  2024-09-01 00:06:31.831           PS COVID
# 11141       5744815  2024-09-01 00:06:31.831           PS COVID
# 11142       5744815  2024-09-01 00:06:31.831           PS COVID
# 11143       5744815  2024-09-01 00:06:31.831           PS COVID
#
#       origem_paciente                                             queixa  \
# 0      MEIOS PRÓPRIOS       REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 1      MEIOS PRÓPRIOS       REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 2      MEIOS PRÓPRIOS       REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 3      MEIOS PRÓPRIOS       REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 4      MEIOS PRÓPRIOS                                          mal estar
# ...               ...                                                ...
# 11139  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
# 11140  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
# 11141  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
# 11142  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
# 11143  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
#
#       info_complementares  usuario     status_ficha  prontuario  \
# 0                    None  H009727       EM TRIAGEM     3677531
# 1                    None  H009727      ENC INTERNO     3677531
# 2                    None  X340740   EM ATENDIMENTO     3677531
# 3                    None  X340740           EVASAO     3677531
# 4                    None  H012966       EM TRIAGEM     1429810
# ...                   ...      ...              ...         ...
# 11139                None  H009727       EM TRIAGEM    90098401
# 11140                None  H009727      ENC INTERNO    90098401
# 11141                None  X182302   EM ATENDIMENTO    90098401
# 11142                None  X182302  EM PROCEDIMENTO    90098401
# 11143                None  X182302      ALTA MEDICA    90098401
#
#                      data_mvto                            nome
# 0      2024-09-09 23:54:06.624  VINICIUS NASCIMENTO DOS SANTOS
# 1      2024-09-09 23:54:53.538  VINICIUS NASCIMENTO DOS SANTOS
# 2      2024-09-10 04:30:53.015  VINICIUS NASCIMENTO DOS SANTOS
# 3      2024-09-10 04:30:58.529  VINICIUS NASCIMENTO DOS SANTOS
# 4      2024-09-09 23:45:39.069  BENEDITO BERNARDINO DOS SANTOS
# ...                        ...                             ...
# 11139  2024-09-01 00:05:38.415          GUSTAVO ALVES TEIXEIRA
# 11140   2024-09-01 00:06:31.99          GUSTAVO ALVES TEIXEIRA
# 11141  2024-09-01 01:17:42.301          GUSTAVO ALVES TEIXEIRA
# 11142  2024-09-01 01:20:26.524          GUSTAVO ALVES TEIXEIRA
# 11143  2024-09-01 04:38:31.942          GUSTAVO ALVES TEIXEIRA
#
# [11144 rows x 11 columns]

# %%
filtered_df.head()
# Out:
#     cod_consulta              dt_consulta                         setor  \
# 3        5771558  2024-09-09 23:54:53.217             PS CLÍNICA MÉDICA
# 25       5771550  2024-09-09 23:10:29.903             PS CIRURGIA GERAL
# 29       5771548  2024-09-09 23:03:41.355  PS ORTOPEDIA E TRAUMATOLOGIA
# 34       5771547  2024-09-09 22:51:25.589             PS CLÍNICA MÉDICA
# 40       5771546  2024-09-09 22:47:28.063                          None
#
#    origem_paciente                                             queixa  \
# 3   MEIOS PRÓPRIOS       REFERE DIARREIA, VOMITO , FRAQUEZA HA 3 DIAS
# 25  MEIOS PRÓPRIOS          REFERE ABCESSO EM BOLSA ESCROTAL HA 1 DIA
# 29  MEIOS PRÓPRIOS                               DOR NA COLUNA LOMBAR
# 34  MEIOS PRÓPRIOS  REFERE DOR ABDOMINAL E ALTERAÇÃO DO HÁBITO INT...
# 40  MEIOS PRÓPRIOS  REFERE TER COLOCADO SVD ONTEM E HOJE COMEÇOU A...
#
#    info_complementares  usuario status_ficha  prontuario  \
# 3                 None  X340740       EVASAO     3677531
# 25                None  R938239  ALTA MEDICA    90105354
# 29                None  H852958  ALTA MEDICA    90105347
# 34                None  X340740  ALTA MEDICA    90050832
# 40                None  X182302  ALTA MEDICA    10529758
#
#                   data_mvto                            nome
# 3   2024-09-10 04:30:58.529  VINICIUS NASCIMENTO DOS SANTOS
# 25  2024-09-10 02:46:54.391              MARCIO REIS COELHO
# 29  2024-09-09 23:11:35.272     INDRA MILARDE MUNIZ FREITAS
# 34   2024-09-10 03:58:16.63       WAGNER RODRIGUES DA SILVA
# 40  2024-09-10 02:54:05.165                  ADEMAR ANSELMO

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = filtered_df.duplicated(subset='cod_consulta', keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(filtered_df[duplicates])
# Out:
# Duplicated entries based on cod_consulta:
#        cod_consulta              dt_consulta                         setor  \
# 363         5771395  2024-09-09 15:53:08.308             PS CLÍNICA MÉDICA
# 364         5771395  2024-09-09 15:53:08.308             PS CLÍNICA MÉDICA
# 510         5770190  2024-09-09 14:49:02.872             PS CLÍNICA MÉDICA
# 512         5770190  2024-09-09 14:49:02.872             PS CLÍNICA MÉDICA
# 624         5769873  2024-09-09 13:48:00.241                      PS COVID
# ...             ...                      ...                           ...
# 9976        5745339  2024-09-02 09:35:08.731  PS ORTOPEDIA E TRAUMATOLOGIA
# 10327       5745093   2024-09-02 06:51:05.22                          None
# 10328       5745093   2024-09-02 06:51:05.22                          None
# 10964       5744881  2024-09-01 11:03:15.064  PS ORTOPEDIA E TRAUMATOLOGIA
# 10965       5744881  2024-09-01 11:03:15.064  PS ORTOPEDIA E TRAUMATOLOGIA
#
#       origem_paciente                                             queixa  \
# 363    MEIOS PRÓPRIOS                    CORIZA / TOSSE / DOR NAS COSTAS
# 364    MEIOS PRÓPRIOS                    CORIZA / TOSSE / DOR NAS COSTAS
# 510    MEIOS PRÓPRIOS                                       DOR MUSCULAR
# 512    MEIOS PRÓPRIOS                                       DOR MUSCULAR
# 624    MEIOS PRÓPRIOS              DOR DE CABECA / DOR NO CORPO  / FEBRE
# ...               ...                                                ...
# 9976   MEIOS PRÓPRIOS                     DOR NA MÃO \r\nACD DO TRABALHO
# 10327  MEIOS PRÓPRIOS                                            RETORNO
# 10328  MEIOS PRÓPRIOS                                            RETORNO
# 10964  MEIOS PRÓPRIOS  REFERE SE CRISE EM HÉRNIA DE DISCO. NÃO CONSEG...
# 10965  MEIOS PRÓPRIOS  REFERE SE CRISE EM HÉRNIA DE DISCO. NÃO CONSEG...
#
#       info_complementares  usuario status_ficha  prontuario  \
# 363                  None  X182302       EVASAO    12099214
# 364                  None  X182302  ALTA MEDICA    12099214
# 510                  None  H574177       EVASAO    10068955
# 512                  None  H853141  ALTA MEDICA    10068955
# 624                  None  X119451  ALTA MEDICA    11097995
# ...                   ...      ...          ...         ...
# 9976                 None  R938230  ALTA MEDICA    11190196
# 10327                None  R938595  ALTA MEDICA    90101197
# 10328                None  X183326  ALTA MEDICA    90101197
# 10964                None  R937746       EVASAO    12380887
# 10965                None  R937746  ALTA MEDICA    12380887
#
#                      data_mvto                                       nome
# 363    2024-09-09 23:57:05.555         RENATA CASSEL DA ROCHA DE MEDEIROS
# 364    2024-09-10 00:52:42.827         RENATA CASSEL DA ROCHA DE MEDEIROS
# 510     2024-09-09 18:52:54.48  LAIS SEBASTIANA GRACIANO DE SOUZA PEREIRA
# 512    2024-09-09 17:35:11.868  LAIS SEBASTIANA GRACIANO DE SOUZA PEREIRA
# 624    2024-09-09 18:20:06.364                  PATRICIA ALQUEJA MONTEIRO
# ...                        ...                                        ...
# 9976   2024-09-02 10:51:23.012    MARIA DAS DORES DE CARVALHO VASCONCELOS
# 10327  2024-09-02 15:12:49.485         JANDIRA RODRIGUES DE ARAUJO SANTOS
# 10328  2024-09-02 16:52:15.774         JANDIRA RODRIGUES DE ARAUJO SANTOS
# 10964  2024-09-01 16:40:40.719                        MATHEUS PINTO COSTA
# 10965  2024-09-01 17:18:05.851                        MATHEUS PINTO COSTA
#
# [97 rows x 11 columns]

# %%
filtered_df[duplicates].head()
# Out:
#      cod_consulta              dt_consulta              setor origem_paciente  \
# 363       5771395  2024-09-09 15:53:08.308  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 364       5771395  2024-09-09 15:53:08.308  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 510       5770190  2024-09-09 14:49:02.872  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 512       5770190  2024-09-09 14:49:02.872  PS CLÍNICA MÉDICA  MEIOS PRÓPRIOS
# 624       5769873  2024-09-09 13:48:00.241           PS COVID  MEIOS PRÓPRIOS
#
#                                     queixa info_complementares  usuario  \
# 363        CORIZA / TOSSE / DOR NAS COSTAS                None  X182302
# 364        CORIZA / TOSSE / DOR NAS COSTAS                None  X182302
# 510                           DOR MUSCULAR                None  H574177
# 512                           DOR MUSCULAR                None  H853141
# 624  DOR DE CABECA / DOR NO CORPO  / FEBRE                None  X119451
#
#     status_ficha  prontuario                data_mvto  \
# 363       EVASAO    12099214  2024-09-09 23:57:05.555
# 364  ALTA MEDICA    12099214  2024-09-10 00:52:42.827
# 510       EVASAO    10068955   2024-09-09 18:52:54.48
# 512  ALTA MEDICA    10068955  2024-09-09 17:35:11.868
# 624  ALTA MEDICA    11097995  2024-09-09 18:20:06.364
#
#                                           nome
# 363         RENATA CASSEL DA ROCHA DE MEDEIROS
# 364         RENATA CASSEL DA ROCHA DE MEDEIROS
# 510  LAIS SEBASTIANA GRACIANO DE SOUZA PEREIRA
# 512  LAIS SEBASTIANA GRACIANO DE SOUZA PEREIRA
# 624                  PATRICIA ALQUEJA MONTEIRO

# %%
filtered_df
# Out:
#        cod_consulta              dt_consulta                         setor  \
# 25          5771550  2024-09-09 23:10:29.903             PS CIRURGIA GERAL
# 29          5771548  2024-09-09 23:03:41.355  PS ORTOPEDIA E TRAUMATOLOGIA
# 34          5771547  2024-09-09 22:51:25.589             PS CLÍNICA MÉDICA
# 40          5771546  2024-09-09 22:47:28.063                          None
# 44          5771544   2024-09-09 22:44:29.85             PS CLÍNICA MÉDICA
# ...             ...                      ...                           ...
# 11118       5744826  2024-09-01 00:36:32.033             PS CLÍNICA MÉDICA
# 11126       5744822  2024-09-01 00:12:29.149             PS CIRURGIA GERAL
# 11130       5744820  2024-09-01 00:11:03.691             PS CLÍNICA MÉDICA
# 11133       5744818  2024-09-01 00:04:26.282             PS CLÍNICA MÉDICA
# 11143       5744815  2024-09-01 00:06:31.831                      PS COVID
#
#       origem_paciente                                             queixa  \
# 25     MEIOS PRÓPRIOS          REFERE ABCESSO EM BOLSA ESCROTAL HA 1 DIA
# 29     MEIOS PRÓPRIOS                               DOR NA COLUNA LOMBAR
# 34     MEIOS PRÓPRIOS  REFERE DOR ABDOMINAL E ALTERAÇÃO DO HÁBITO INT...
# 40     MEIOS PRÓPRIOS  REFERE TER COLOCADO SVD ONTEM E HOJE COMEÇOU A...
# 44     MEIOS PRÓPRIOS  APRESENTA CARTA DE ENCAMINHAMENTO PARA REAVALI...
# ...               ...                                                ...
# 11118  MEIOS PRÓPRIOS                   cefaleia com do no olho esquerdo
# 11126  MEIOS PRÓPRIOS                                      QUEDA DA CAMA
# 11130  MEIOS PRÓPRIOS                                       DOR NO CORPO
# 11133  MEIOS PRÓPRIOS                                             fadiga
# 11143  MEIOS PRÓPRIOS  FALTA DE AR, TOSSE SECRETIVA HA 30 DIAS DISPIN...
#
#       info_complementares  usuario status_ficha  prontuario  \
# 25                   None  R938239  ALTA MEDICA    90105354
# 29                   None  H852958  ALTA MEDICA    90105347
# 34                   None  X340740  ALTA MEDICA    90050832
# 40                   None  X182302  ALTA MEDICA    10529758
# 44                   None  X182302  ALTA MEDICA    12165098
# ...                   ...      ...          ...         ...
# 11118                None  X182302  ALTA MEDICA    11975398
# 11126                None  R938588  ALTA MEDICA    12022356
# 11130                None  X182302  ALTA MEDICA    10371441
# 11133                None  R938588  ALTA MEDICA     4471678
# 11143                None  X182302  ALTA MEDICA    90098401
#
#                      data_mvto                                 nome
# 25     2024-09-10 02:46:54.391                   MARCIO REIS COELHO
# 29     2024-09-09 23:11:35.272          INDRA MILARDE MUNIZ FREITAS
# 34      2024-09-10 03:58:16.63            WAGNER RODRIGUES DA SILVA
# 40     2024-09-10 02:54:05.165                       ADEMAR ANSELMO
# 44     2024-09-10 03:45:42.056                 ANA PAULA DOS SANTOS
# ...                        ...                                  ...
# 11118  2024-09-01 04:23:25.857          JOAO AUGUSTO DE LIMA SANTOS
# 11126  2024-09-01 01:36:18.407               LIVIA STAMPFER ANDRADE
# 11130  2024-09-01 01:33:20.977     GRAZIANE CARDOSO CASTALDI CALDIN
# 11133  2024-09-01 00:50:54.345  DOUGLAS PEREIRA PINTO  - ATUALIZAR-
# 11143  2024-09-01 04:38:31.942               GUSTAVO ALVES TEIXEIRA
#
# [2161 rows x 11 columns]

# %%
# Selecting specific columns
selected_columns_df = filtered_df[['cod_consulta', 'dt_consulta', 'nome','data_mvto']]

# %%
selected_columns_df.shape[0]
# Out:
# 2161

# %%
df_ficha_acolhido_medico_baixa.shape[0]
# Out:
# 2295

# %%
df_relatorio = pd.merge(df_ficha_acolhido_medico_baixa, selected_columns_df, on="cod_consulta")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-eae85a575305> in <module>
# ----> 1 df_relatorio = pd.merge(df_ficha_acolhido_medico_baixa, selected_columns_df, on="cod_consulta")
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     735             self.right_join_keys,
#     736             self.join_names,
# --> 737         ) = self._get_merge_keys()
#     738
#     739         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1219                         #  the latter of which will raise
#    1220                         lk = cast(Hashable, lk)
# -> 1221                         left_keys.append(left._get_label_or_level_values(lk))
#    1222                         join_names.append(lk)
#    1223                     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#
# KeyError: 'cod_consulta'

# %%
df_relatorio.shape[0]
# Out:
# 2169

# %%
# Check for duplicates in the 'cod_consulta' column
duplicates = df_ficha_acolhido_medico_baixa.duplicated(subset='con_numero', keep=False)

# Display the duplicated rows
print("Duplicated entries based on cod_consulta:")
print(df_ficha_acolhido_medico_baixa[duplicates])
# Out:
# Duplicated entries based on cod_consulta:
#       rf_profissional                      nome_profissional  usuario  \
# 12              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 13              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 24              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 25              34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 26            5741777  NEUZA ALICE NOBUKO SAWADA CHIMABUCURO  H574177
# ...               ...                                    ...      ...
# 2197         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2198         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2212         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2213         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
# 2214         50628212     ERICK FLECKENSTEIN GALLETTI CHAVES  X506282
#
#       prontuario  con_numero  trg_seq  seqp data_consulta  cod_status  \
# 12      10564888     5749511   225090     5    2024-09-03           6
# 13      10564888     5749511   225090     5    2024-09-03           6
# 24      90096520     5749143   224994     5    2024-09-03           6
# 25      90096520     5749143   224994     5    2024-09-03           6
# 26      90096520     5749400   225052     8    2024-09-03          22
# ...          ...         ...      ...   ...           ...         ...
# 2197    12090973     5754320   225670     5    2024-09-04           6
# 2198    12090973     5754320   225670     5    2024-09-04           6
# 2212    12144846     5752116   225432     5    2024-09-04           6
# 2213    12144846     5752116   225432     5    2024-09-04           6
# 2214    12144846     5752116   225432     5    2024-09-04           6
#
#                status_ficha_x                data_mvto data_acolhimento  \
# 12                ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 13                ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 24                ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 25                ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 26    ALTA COM ENCAMINHAMENTO  2024-09-03 14:17:02.884       2024-09-03
# ...                       ...                      ...              ...
# 2197              ALTA MEDICA  2024-09-04 16:37:22.542       2024-09-04
# 2198              ALTA MEDICA  2024-09-04 16:37:22.542       2024-09-04
# 2212              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
# 2213              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
# 2214              ALTA MEDICA  2024-09-04 09:31:41.596       2024-09-04
#
#      status_ficha_y origem_paciente  \
# 12      ENC TRIAGEM  MEIOS PRÓPRIOS
# 13      ENC TRIAGEM  MEIOS PRÓPRIOS
# 24      ENC TRIAGEM  MEIOS PRÓPRIOS
# 25      ENC TRIAGEM  MEIOS PRÓPRIOS
# 26      ENC TRIAGEM  MEIOS PRÓPRIOS
# ...             ...             ...
# 2197    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2198    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2212    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2213    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2214    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                  queixa  \
# 12    REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 13    REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 24                          DOR NAS PERNAS, VERMELHIDAO
# 25                                            MEDICACAO
# 26                          DOR NAS PERNAS, VERMELHIDAO
# ...                                                 ...
# 2197                                             coriza
# 2198                                             coriza
# 2212                                              TOSSE
# 2213                                              TOSSE
# 2214                                              TOSSE
#
#      informacoes_complementares usuario_acolhimento  \
# 12                         None             H010367
# 13                         None             H010367
# 24                         None             H013216
# 25                         None             H013216
# 26                         None             H013216
# ...                         ...                 ...
# 2197                       None             H013147
# 2198                       None             H013147
# 2212                       None             H010269
# 2213                       None             H010269
# 2214                       None             H010269
#
#                              nome descricao
# 12            FLAVIA DESTRO SILVA     VERDE
# 13            FLAVIA DESTRO SILVA     VERDE
# 24    WANDERLIN DE SANTANA PASSOS     VERDE
# 25    WANDERLIN DE SANTANA PASSOS    BRANCO
# 26    WANDERLIN DE SANTANA PASSOS     VERDE
# ...                           ...       ...
# 2197   VALDERINO APARECIDO VALINO     VERDE
# 2198   VALDERINO APARECIDO VALINO     VERDE
# 2212            DULCINEIA FERRARI     VERDE
# 2213            DULCINEIA FERRARI     VERDE
# 2214            DULCINEIA FERRARI     VERDE
#
# [280 rows x 19 columns]

# %%
df_ficha_acolhido_medico_baixa.head()
# Out:
#    rf_profissional              nome_profissional  usuario  prontuario  \
# 0            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 1            34177  TYANNA MARIA BONFIM DE MORAES  X055670      749135
# 2            34177  TYANNA MARIA BONFIM DE MORAES  X055670     4916920
# 3            34177  TYANNA MARIA BONFIM DE MORAES  X055670    12169959
# 4            34177  TYANNA MARIA BONFIM DE MORAES  X055670     3324290
#
#    con_numero  trg_seq  seqp data_consulta  cod_status status_ficha_x  \
# 0     5751794   225157     8    2024-09-03           6    ALTA MEDICA
# 1     5750514   225157     8    2024-09-03           6    ALTA MEDICA
# 2     5750528   225168     5    2024-09-03           6    ALTA MEDICA
# 3     5750520   225162     5    2024-09-03           6    ALTA MEDICA
# 4     5750516   225160     5    2024-09-03           6    ALTA MEDICA
#
#                  data_mvto data_acolhimento status_ficha_y origem_paciente  \
# 0  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 1  2024-09-03 17:44:19.406       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 2  2024-09-03 18:50:11.274       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 3  2024-09-03 17:52:42.316       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
# 4  2024-09-03 18:14:43.326       2024-09-03    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                               queixa  \
# 0  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 1  VERMELHIDAO EM MMII, FEZ US E ENCAMINHADA PRO ...
# 2  DOR NO PEITO A 7 DIAS, FEZ O USO DE DIPIRONA, ...
# 3                                          S GRIPAIS
# 4                                      DOR AO URINAR
#
#   informacoes_complementares usuario_acolhimento  \
# 0                       None             H013216
# 1                       None             H013216
# 2                       None             H013216
# 3                       None             H012077
# 4                       None             H013216
#
#                               nome descricao
# 0          DALVA SANTOS DE QUEIROZ     VERDE
# 1          DALVA SANTOS DE QUEIROZ     VERDE
# 2     EDINA MATIAS GONSALES BONHIN     VERDE
# 3  ALGACIR LEITE DE ALMEIDA JUNIOR     VERDE
# 4       DAISY DE MEDEIROS MELCHIOR     VERDE

# %%
df_ficha_acolhido_medico_baixa[duplicates].head()
# Out:
#     rf_profissional                      nome_profissional  usuario  \
# 12            34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 13            34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 24            34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 25            34177          TYANNA MARIA BONFIM DE MORAES  X055670
# 26          5741777  NEUZA ALICE NOBUKO SAWADA CHIMABUCURO  H574177
#
#     prontuario  con_numero  trg_seq  seqp data_consulta  cod_status  \
# 12    10564888     5749511   225090     5    2024-09-03           6
# 13    10564888     5749511   225090     5    2024-09-03           6
# 24    90096520     5749143   224994     5    2024-09-03           6
# 25    90096520     5749143   224994     5    2024-09-03           6
# 26    90096520     5749400   225052     8    2024-09-03          22
#
#              status_ficha_x                data_mvto data_acolhimento  \
# 12              ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 13              ALTA MEDICA  2024-09-03 15:13:53.718       2024-09-03
# 24              ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 25              ALTA MEDICA  2024-09-03 09:11:48.828       2024-09-03
# 26  ALTA COM ENCAMINHAMENTO  2024-09-03 14:17:02.884       2024-09-03
#
#    status_ficha_y origem_paciente  \
# 12    ENC TRIAGEM  MEIOS PRÓPRIOS
# 13    ENC TRIAGEM  MEIOS PRÓPRIOS
# 24    ENC TRIAGEM  MEIOS PRÓPRIOS
# 25    ENC TRIAGEM  MEIOS PRÓPRIOS
# 26    ENC TRIAGEM  MEIOS PRÓPRIOS
#
#                                                queixa  \
# 12  REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 13  REFERE SE MIALGIA, CEFALEIA, DIARREIA, SENSAÇÃ...
# 24                        DOR NAS PERNAS, VERMELHIDAO
# 25                                          MEDICACAO
# 26                        DOR NAS PERNAS, VERMELHIDAO
#
#    informacoes_complementares usuario_acolhimento  \
# 12                       None             H010367
# 13                       None             H010367
# 24                       None             H013216
# 25                       None             H013216
# 26                       None             H013216
#
#                            nome descricao
# 12          FLAVIA DESTRO SILVA     VERDE
# 13          FLAVIA DESTRO SILVA     VERDE
# 24  WANDERLIN DE SANTANA PASSOS     VERDE
# 25  WANDERLIN DE SANTANA PASSOS    BRANCO
# 26  WANDERLIN DE SANTANA PASSOS     VERDE

# %%
df_ficha_acolhido_medico_baixa.shape[0]
# Out:
# 2295
